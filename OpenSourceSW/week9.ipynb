# %%
x=float(input("x = "))
y=3*x*x+5*x+3
print("y =",y)
# Out:
# x = 3
# y = 45.0

# %%
r=float(input("반지름을 입력하세요:"))
pi=3.14
print("원의 둘레 : {0:.2f}".format(2*pi*r))
print("원의 넓이 : {0:.2f}".format(pi*r*r))
# Out:
# 반지름을 입력하세요:3
# 원의 둘레 : 18.84
# 원의 넓이 : 28.26
